# %%
import seaborn as sns

# %%
sns.set(style="dark")

# %%
rad=sns.load_dataset("fmri")

# %%
sns.lineplot(x="timepoint",
             y="signal",
             hue="region",
             style="event",
             data=rad)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>
